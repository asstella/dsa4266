# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelBinarizer
from imblearn.over_sampling import SMOTE

from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense,Dropout,LayerNormalization
from tensorflow.keras.callbacks import EarlyStopping,ReduceLROnPlateau, ModelCheckpoint
from focal_loss import SparseCategoricalFocalLoss
import tensorflow as tf
from tensorflow.keras import layers
from keras_tuner import HyperModel

from sklearn.metrics import classification_report
import matplotlib.pyplot as plt 
from sklearn.metrics import roc_curve, auc

import os

tf.random.set_seed(42)
np.random.seed(42)

# %% [markdown]
# # Reading in pickle files

# %%
X_train = pd.read_pickle('X_train.pkl')
X_test = pd.read_pickle('X_test.pkl')
y_train = pd.read_pickle('y_train.pkl')
y_test = pd.read_pickle('y_test.pkl')

# %% [markdown]
# # Drop frame.time

# %%
X_train.drop(columns=['frame.time'], inplace=True)
X_test.drop(columns=['frame.time'], inplace=True)

# %% [markdown]
# # Separate Normal Traffic and Attack Traffic from data for Training AutoEncoder and FCN

# %%
# Filter only Normal traffic from X_train 
normal_indices = y_train[y_train['Attack_type'] == 12].index
X_train_normal = X_train.iloc[normal_indices]

# Create y_test_label which is binary, 0 for normal 1 for attack
y_test_label = np.where(y_test['Attack_type'] == 12, 0, 1)

# Filter only Attack Traffic from X_train
attack_indices_train = y_train[y_train['Attack_type'] != 12].index
X_train_attack = X_train.iloc[attack_indices_train]
y_train_attack = y_train.iloc[attack_indices_train]

# Create y_test_label which only has attack
attack_indices_test = y_test[y_test['Attack_type'] != 12].index
X_test_attack = X_test.iloc[attack_indices_test]
y_test_attack = y_test.iloc[attack_indices_test]

# %% [markdown]
# # SMOTE

# %%
# SMOTE on Attack Traffic
smote = SMOTE(random_state=42)
X_resampled_attack, y_resampled_attack = smote.fit_resample(X_train_attack, y_train_attack)

# %% [markdown]
# # Fine Tuning

# %%
class AttackFCNHypModel(HyperModel):
    def build(self, hp):
        model = keras.Sequential()
        
        # Hyperparameter for the number of units in the first layer
        model.add(layers.Dense(
        units=hp.Int('units_1', min_value=128, max_value=512, step=64),
        input_dim=X_resampled_attack.shape[1],
        activation='leaky_relu'))
        model.add(layers.Dropout(0.2))

        # Hyperparameter for the number of units in the second layer
        model.add(layers.Dense(
        units=hp.Int('units_2', min_value=64, max_value=256, step=32),
        activation='leaky_relu'))
        model.add(layers.Dropout(0.2))

        # Hyperparameter for the number of units in the third layer
        model.add(layers.Dense(
        units=hp.Int('units_3', min_value=32, max_value=128, step=32),
        activation='leaky_relu'))
        model.add(layers.Dropout(0.2))

        # Hyperparameter for the number of units in the first layer
        model.add(layers.Dense(
        units=hp.Int('units_4', min_value=128, max_value=512, step=64),
        activation='leaky_relu'))
        model.add(layers.LayerNormalization())
        model.add(layers.Dropout(0.2))

        # Output layer
        model.add(layers.Dense(units=12, activation='softmax'))

        # Compile the model with a tunable learning rate
        model.compile(optimizer=keras.optimizers.AdamW(
            learning_rate=0.01),
            loss=SparseCategoricalFocalLoss(hp.Float('focal_loss_gamma', min_value=1.0, max_value=3.0, step=0.5)),
            metrics=['accuracy'])
        
        return model
    
attack_fcn_hypermodel = AttackFCNHypModel()

tuner = kt.Hyperband(
    attack_fcn_hypermodel,
    objective='val_loss',
    max_epochs=100,
    factor=3,
    directory='my_dir',
    project_name='attack_fcn_hyperband')

# Add early stopping to the tuner
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# Add ReduceLROnPlateau to the tuner
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)

tuner.search(X_resampled_attack, y_resampled_attack, epochs=100, validation_split=0.2, callbacks=[stop_early, reduce_lr])

best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
# Out:
# Trial 232 Complete [12h 22m 50s]
# val_loss: 1.1656858921051025
#
# Best val_loss So Far: 0.6945260167121887
# Total elapsed time: 1d 14h 53m 52s
#
# Search: Running Trial #233
#
# Value             |Best Value So Far |Hyperparameter
# 192               |512               |units_1
# 128               |128               |units_2
# 128               |64                |units_3
# 256               |512               |units_4
# 3                 |3                 |focal_loss_gamma
# 34                |100               |tuner/epochs
# 0                 |34                |tuner/initial_epoch
# 1                 |4                 |tuner/bracket
# 0                 |4                 |tuner/round
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/core/dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/34
# 31261/31261 ━━━━━━━━━━━━━━━━━━━━ 38s 1ms/step - accuracy: 0.8162 - loss: 0.2177 - val_accuracy: 0.2232 - val_loss: 1.2166 - learning_rate: 0.0100
# Epoch 2/34
# 31261/31261 ━━━━━━━━━━━━━━━━━━━━ 36s 1ms/step - accuracy: 0.8501 - loss: 0.1669 - val_accuracy: 0.2471 - val_loss: 1.1076 - learning_rate: 0.0100
# Epoch 3/34
# 31261/31261 ━━━━━━━━━━━━━━━━━━━━ 40s 1ms/step - accuracy: 0.8512 - loss: 0.1650 - val_accuracy: 0.2533 - val_loss: 1.1292 - learning_rate: 0.0100
# Epoch 4/34
# 31261/31261 ━━━━━━━━━━━━━━━━━━━━ 37s 1ms/step - accuracy: 0.8511 - loss: 0.1651 - val_accuracy: 0.2444 - val_loss: 1.1943 - learning_rate: 0.0100
# Epoch 5/34
# 31261/31261 ━━━━━━━━━━━━━━━━━━━━ 40s 1ms/step - accuracy: 0.8518 - loss: 0.1644 - val_accuracy: 0.2405 - val_loss: 1.1471 - learning_rate: 0.0100
# Epoch 6/34
# 31261/31261 ━━━━━━━━━━━━━━━━━━━━ 38s 1ms/step - accuracy: 0.8613 - loss: 0.1513 - val_accuracy: 0.2745 - val_loss: 1.0475 - learning_rate: 0.0050
# Epoch 7/34
# 22700/31261 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - accuracy: 0.8612 - loss: 0.1513
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[66], line 63
#      60 # Add ReduceLROnPlateau to the tuner
#      61 reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)
# ---> 63 tuner.search(X_resampled_attack, y_resampled_attack, epochs=100, validation_split=0.2, callbacks=[stop_early, reduce_lr])
#      65 best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras_tuner/src/engine/base_tuner.py:234, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     231         continue
#     233     self.on_trial_begin(trial)
# --> 234     self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     235     self.on_trial_end(trial)
#     236 self.on_search_end()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras_tuner/src/engine/base_tuner.py:274, in BaseTuner._try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     272 def _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
#     273     try:
# --> 274         self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     275         trial.status = trial_module.TrialStatus.COMPLETED
#     276         return
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras_tuner/src/engine/base_tuner.py:239, in BaseTuner._run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     238 def _run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
# --> 239     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     240     if self.oracle.get_trial(trial.trial_id).metrics.exists(
#     241         self.oracle.objective.name
#     242     ):
#     243         # The oracle is updated by calling `self.oracle.update_trial()` in
#     244         # `Tuner.run_trial()`. For backward compatibility, we support this
#     245         # use case. No further action needed in this case.
#     246         warnings.warn(
#     247             "The use case of calling "
#     248             "`self.oracle.update_trial(trial_id, metrics)` "
#    (...)
#     254             stacklevel=2,
#     255         )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras_tuner/src/tuners/hyperband.py:427, in Hyperband.run_trial(self, trial, *fit_args, **fit_kwargs)
#     425     fit_kwargs["epochs"] = hp.values["tuner/epochs"]
#     426     fit_kwargs["initial_epoch"] = hp.values["tuner/initial_epoch"]
# --> 427 return super().run_trial(trial, *fit_args, **fit_kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras_tuner/src/engine/tuner.py:314, in Tuner.run_trial(self, trial, *args, **kwargs)
#     312     callbacks.append(model_checkpoint)
#     313     copied_kwargs["callbacks"] = callbacks
# --> 314     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     316     histories.append(obj_value)
#     317 return histories
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras_tuner/src/engine/tuner.py:233, in Tuner._build_and_fit_model(self, trial, *args, **kwargs)
#     231 hp = trial.hyperparameters
#     232 model = self._try_build(hp)
# --> 233 results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     235 # Save the build config for model loading later.
#     236 if backend.config.multi_backend():
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras_tuner/src/engine/hypermodel.py:149, in HyperModel.fit(self, hp, model, *args, **kwargs)
#     125 def fit(self, hp, model, *args, **kwargs):
#     126     """Train the model.
#     127
#     128     Args:
#    (...)
#     147         If return a float, it should be the `objective` value.
#     148     """
# --> 149     return model.fit(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py:325, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     323 for step, iterator in epoch_iterator.enumerate_epoch():
#     324     callbacks.on_train_batch_begin(step)
# --> 325     logs = self.train_function(iterator)
#     326     callbacks.on_train_batch_end(
#     327         step, self._pythonify_logs(logs)
#     328     )
#     329     if self.stop_training:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# # Final 2 Part Model

# %% [markdown]
# ## AutoEncoder

# %%
# Model
input_dim = X_train_normal.shape[1]

ae_no_time = Sequential()
ae_no_time.add(Dense(units=input_dim, input_dim=input_dim, activation='leaky_relu'))
ae_no_time.add(Dropout(0.2))
ae_no_time.add(Dense(units=128, activation='leaky_relu'))
ae_no_time.add(Dropout(0.2))
ae_no_time.add(Dense(units=64, activation='leaky_relu'))
ae_no_time.add(Dense(units=32, activation='leaky_relu'))
ae_no_time.add(Dense(units=64, activation='leaky_relu'))
ae_no_time.add(Dropout(0.2))
ae_no_time.add(Dense(units=128, activation='leaky_relu'))
ae_no_time.add(Dropout(0.2))
ae_no_time.add(Dense(units=input_dim, activation='leaky_relu'))
 
ae_no_time.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss',  # Metric to monitor
                               patience=7,          # Number of epochs to wait after no improvement
                               restore_best_weights=True)  # Restores model to the best weights when stopped

reduce_lr = ReduceLROnPlateau(monitor='val_loss',    # Metric to monitor
                              factor=0.5,           # Factor by which to reduce the learning rate
                              patience=5,           # Number of epochs with no improvement before reducing LR
                              min_lr=1e-6)  

# Train using normal traffic data for both inputs and outputs
ae_no_time_hist = ae_no_time.fit(X_train_normal, X_train_normal,  
                epochs=100,                   
                batch_size=500,
                validation_split=0.2,
                callbacks = [early_stopping,reduce_lr])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/core/dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 1371/1371 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.3235 - loss: 0.0158 - val_accuracy: 0.5618 - val_loss: 3.9017e-04 - learning_rate: 0.0010
# Epoch 2/100
# 1371/1371 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.4563 - loss: 0.0020 - val_accuracy: 0.4984 - val_loss: 2.5891e-04 - learning_rate: 0.0010
# Epoch 3/100
# 1371/1371 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.4733 - loss: 0.0015 - val_accuracy: 0.4784 - val_loss: 2.0588e-04 - learning_rate: 0.0010
# Epoch 4/100
# 1371/1371 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.4761 - loss: 0.0012 - val_accuracy: 0.4297 - val_loss: 1.6969e-04 - learning_rate: 0.0010
# Epoch 5/100
# 1371/1371 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.4797 - loss: 9.9229e-04 - val_accuracy: 0.4802 - val_loss: 1.4792e-04 - learning_rate: 0.0010
# Epoch 6/100
# 1371/1371 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.4813 - loss: 8.9247e-04 - val_accuracy: 0.4320 - val_loss: 1.4746e-04 - learning_rate: 0.0010
# Epoch 7/100
# 1371/1371 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.4835 - loss: 8.4220e-04 - val_accuracy: 0.4676 - val_loss: 1.3066e-04 - learning_rate: 0.0010
# Epoch 8/100
# 1371/1371 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.4853 - loss: 8.0221e-04 - val_accuracy: 0.4397 - val_loss: 1.4607e-04 - learning_rate: 0.0010
# Epoch 9/100
# 1371/1371 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.4856 - loss: 7.7785e-04 - val_accuracy: 0.4567 - val_loss: 1.4178e-04 - learning_rate: 0.0010
# Epoch 10/100
# 1371/1371 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.4905 - loss: 7.6199e-04 - val_accuracy: 0.5448 - val_loss: 1.2248e-04 - learning_rate: 0.0010
# Epoch 11/100
# 1371/1371 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.4964 - loss: 7.3320e-04 - val_accuracy: 0.5071 - val_loss: 1.3166e-04 - learning_rate: 5.0000e-04
# Epoch 12/100
# 1371/1371 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.4987 - loss: 7.2504e-04 - val_accuracy: 0.6190 - val_loss: 1.2978e-04 - learning_rate: 5.0000e-04
# Epoch 13/100
# 1371/1371 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.5028 - loss: 7.1673e-04 - val_accuracy: 0.5602 - val_loss: 1.4739e-04 - learning_rate: 5.0000e-04
# Epoch 14/100
# 1371/1371 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.5051 - loss: 7.0901e-04 - val_accuracy: 0.5382 - val_loss: 1.5182e-04 - learning_rate: 5.0000e-04
# Epoch 15/100
# 1371/1371 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.5082 - loss: 7.0442e-04 - val_accuracy: 0.4517 - val_loss: 1.6235e-04 - learning_rate: 5.0000e-04
# Epoch 16/100
# 1371/1371 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.5082 - loss: 6.8530e-04 - val_accuracy: 0.5097 - val_loss: 1.6618e-04 - learning_rate: 2.5000e-04
# Epoch 17/100
# 1371/1371 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.5100 - loss: 6.8193e-04 - val_accuracy: 0.5355 - val_loss: 1.6560e-04 - learning_rate: 2.5000e-04

# %%
# Training and Validation Loss Plots
plt.plot(ae_no_time_hist.history['loss'], label='Training Loss', marker='o', color='darkblue')
plt.plot(ae_no_time_hist.history['val_loss'], label='Val_Loss', marker='o', color='red')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
###################################################################################################
# Predictions
ae_no_time_pred = ae_no_time.predict(X_test)
# MSE between true X_test and pred_X_test
mse_no_time = np.mean(np.power(X_test - ae_no_time_pred, 2), axis=1)

###################################################################################################
# Plot the ROC curve
fpr, tpr, thresholds = roc_curve(y_test_label, mse_no_time)
youden_index = np.argmax(tpr - fpr)
optimal_threshold = thresholds[youden_index]

###################################################################################################
# Identify Anomaly based on MSE Threshold
threshold = optimal_threshold
anomaly_labels_no_time = np.where(mse_no_time > threshold, 1, 0)

###################################################################################################
#  Classification Report 
print(classification_report(y_test_label, anomaly_labels_no_time))

###################################################################################################
# ROC Curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label="ROC Curve")
plt.xlabel("False Positive Rate (FPR)")
plt.ylabel("True Positive Rate (TPR)")
plt.legend()
plt.show()
# Out:
# 19852/19852 ━━━━━━━━━━━━━━━━━━━━ 5s 264us/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    367217
#            1       1.00      1.00      1.00    268028
#
#     accuracy                           1.00    635245
#    macro avg       1.00      1.00      1.00    635245
# weighted avg       1.00      1.00      1.00    635245

# %% [markdown]
# ## Fully Connected Network

# %%
# Model
attack_FCN_no_time = Sequential()
attack_FCN_no_time.add(Dense(units=448, input_dim=X_train_attack.shape[1],activation='leaky_relu'))
attack_FCN_no_time.add(LayerNormalization())
attack_FCN_no_time.add(Dropout(0.2))

attack_FCN_no_time.add(Dense(units=128,activation='leaky_relu'))
attack_FCN_no_time.add(LayerNormalization())

attack_FCN_no_time.add(Dense(units=128,activation='leaky_relu'))
attack_FCN_no_time.add(LayerNormalization())
attack_FCN_no_time.add(Dropout(0.2))

attack_FCN_no_time.add(Dense(units=192,activation='leaky_relu'))
attack_FCN_no_time.add(LayerNormalization())

attack_FCN_no_time.add(Dense(units=12, activation='softmax'))

attack_FCN_no_time.compile(optimizer='adamw', loss= SparseCategoricalFocalLoss(gamma = 3), metrics=['accuracy'])

checkpoint_path = "best_model.weights.h5"
checkpoint_callback = ModelCheckpoint(
    checkpoint_path, 
    monitor='val_loss',   
    save_best_only=True, 
    save_weights_only=True, 
    verbose=1
)

reduce_lr = ReduceLROnPlateau(monitor='val_loss',    # Metric to monitor
                              factor=0.5,           # Factor by which to reduce the learning rate
                              patience=10,           # Number of epochs with no improvement before reducing LR
                              min_lr=1e-6)  

attack_FCN_no_time_hist = attack_FCN_no_time.fit(X_train_attack, y_train_attack, batch_size=500, epochs=250,callbacks=[checkpoint_callback,reduce_lr],validation_split=0.2)
# Out:
# Epoch 1/250
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/core/dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#  997/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7784 - loss: 0.3076
# Epoch 1: val_loss improved from inf to 0.19119, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7785 - loss: 0.3072 - val_accuracy: 0.8360 - val_loss: 0.1912 - learning_rate: 0.0010
# Epoch 2/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8320 - loss: 0.1930
# Epoch 2: val_loss improved from 0.19119 to 0.18777, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8320 - loss: 0.1930 - val_accuracy: 0.8371 - val_loss: 0.1878 - learning_rate: 0.0010
# Epoch 3/250
#  994/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8359 - loss: 0.1873
# Epoch 3: val_loss improved from 0.18777 to 0.18726, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8359 - loss: 0.1873 - val_accuracy: 0.8388 - val_loss: 0.1873 - learning_rate: 0.0010
# Epoch 4/250
#  995/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8378 - loss: 0.1848
# Epoch 4: val_loss improved from 0.18726 to 0.18671, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8378 - loss: 0.1848 - val_accuracy: 0.8384 - val_loss: 0.1867 - learning_rate: 0.0010
# Epoch 5/250
#  997/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8399 - loss: 0.1823
# Epoch 5: val_loss improved from 0.18671 to 0.18497, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8399 - loss: 0.1823 - val_accuracy: 0.8399 - val_loss: 0.1850 - learning_rate: 0.0010
# Epoch 6/250
#  995/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8417 - loss: 0.1798
# Epoch 6: val_loss improved from 0.18497 to 0.17713, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8417 - loss: 0.1798 - val_accuracy: 0.8462 - val_loss: 0.1771 - learning_rate: 0.0010
# Epoch 7/250
#  998/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8441 - loss: 0.1756
# Epoch 7: val_loss improved from 0.17713 to 0.17183, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8441 - loss: 0.1756 - val_accuracy: 0.8491 - val_loss: 0.1718 - learning_rate: 0.0010
# Epoch 8/250
#  994/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8477 - loss: 0.1722
# Epoch 8: val_loss did not improve from 0.17183
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8477 - loss: 0.1722 - val_accuracy: 0.8491 - val_loss: 0.1726 - learning_rate: 0.0010
# Epoch 9/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8507 - loss: 0.1687
# Epoch 9: val_loss improved from 0.17183 to 0.16159, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8507 - loss: 0.1687 - val_accuracy: 0.8591 - val_loss: 0.1616 - learning_rate: 0.0010
# Epoch 10/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8542 - loss: 0.1656
# Epoch 10: val_loss improved from 0.16159 to 0.16052, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8542 - loss: 0.1656 - val_accuracy: 0.8619 - val_loss: 0.1605 - learning_rate: 0.0010
# Epoch 11/250
#  994/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8572 - loss: 0.1623
# Epoch 11: val_loss improved from 0.16052 to 0.15539, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8572 - loss: 0.1623 - val_accuracy: 0.8672 - val_loss: 0.1554 - learning_rate: 0.0010
# Epoch 12/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8581 - loss: 0.1614
# Epoch 12: val_loss did not improve from 0.15539
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8581 - loss: 0.1614 - val_accuracy: 0.8559 - val_loss: 0.1632 - learning_rate: 0.0010
# Epoch 13/250
#  999/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8593 - loss: 0.1606
# Epoch 13: val_loss did not improve from 0.15539
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8593 - loss: 0.1606 - val_accuracy: 0.8629 - val_loss: 0.1578 - learning_rate: 0.0010
# Epoch 14/250
#  998/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8615 - loss: 0.1571
# Epoch 14: val_loss did not improve from 0.15539
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8615 - loss: 0.1571 - val_accuracy: 0.8618 - val_loss: 0.1582 - learning_rate: 0.0010
# Epoch 15/250
#  999/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8593 - loss: 0.1585
# Epoch 15: val_loss improved from 0.15539 to 0.15175, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8593 - loss: 0.1585 - val_accuracy: 0.8673 - val_loss: 0.1517 - learning_rate: 0.0010
# Epoch 16/250
#  995/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8612 - loss: 0.1575
# Epoch 16: val_loss improved from 0.15175 to 0.14623, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8612 - loss: 0.1575 - val_accuracy: 0.8744 - val_loss: 0.1462 - learning_rate: 0.0010
# Epoch 17/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8618 - loss: 0.1567
# Epoch 17: val_loss did not improve from 0.14623
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8618 - loss: 0.1567 - val_accuracy: 0.8640 - val_loss: 0.1580 - learning_rate: 0.0010
# Epoch 18/250
#  995/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8629 - loss: 0.1555
# Epoch 18: val_loss did not improve from 0.14623
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8629 - loss: 0.1554 - val_accuracy: 0.8682 - val_loss: 0.1515 - learning_rate: 0.0010
# Epoch 19/250
#  999/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8654 - loss: 0.1523
# Epoch 19: val_loss did not improve from 0.14623
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8654 - loss: 0.1523 - val_accuracy: 0.8529 - val_loss: 0.1637 - learning_rate: 0.0010
# Epoch 20/250
#  999/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8670 - loss: 0.1510
# Epoch 20: val_loss improved from 0.14623 to 0.14419, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8670 - loss: 0.1510 - val_accuracy: 0.8751 - val_loss: 0.1442 - learning_rate: 0.0010
# Epoch 21/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8659 - loss: 0.1520
# Epoch 21: val_loss improved from 0.14419 to 0.13940, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8659 - loss: 0.1520 - val_accuracy: 0.8790 - val_loss: 0.1394 - learning_rate: 0.0010
# Epoch 22/250
#  999/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8679 - loss: 0.1493
# Epoch 22: val_loss did not improve from 0.13940
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8679 - loss: 0.1493 - val_accuracy: 0.8713 - val_loss: 0.1480 - learning_rate: 0.0010
# Epoch 23/250
#  994/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8673 - loss: 0.1501
# Epoch 23: val_loss did not improve from 0.13940
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8673 - loss: 0.1501 - val_accuracy: 0.8721 - val_loss: 0.1446 - learning_rate: 0.0010
# Epoch 24/250
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8667 - loss: 0.1511
# Epoch 24: val_loss did not improve from 0.13940
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8667 - loss: 0.1511 - val_accuracy: 0.8770 - val_loss: 0.1399 - learning_rate: 0.0010
# Epoch 25/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8677 - loss: 0.1493
# Epoch 25: val_loss did not improve from 0.13940
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8677 - loss: 0.1493 - val_accuracy: 0.8692 - val_loss: 0.1487 - learning_rate: 0.0010
# Epoch 26/250
#  999/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8630 - loss: 0.1555
# Epoch 26: val_loss did not improve from 0.13940
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8630 - loss: 0.1555 - val_accuracy: 0.8531 - val_loss: 0.1655 - learning_rate: 0.0010
# Epoch 27/250
#  994/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8675 - loss: 0.1499
# Epoch 27: val_loss improved from 0.13940 to 0.13853, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8675 - loss: 0.1499 - val_accuracy: 0.8803 - val_loss: 0.1385 - learning_rate: 0.0010
# Epoch 28/250
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8688 - loss: 0.1480
# Epoch 28: val_loss improved from 0.13853 to 0.13702, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8688 - loss: 0.1480 - val_accuracy: 0.8807 - val_loss: 0.1370 - learning_rate: 0.0010
# Epoch 29/250
#  996/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8681 - loss: 0.1492
# Epoch 29: val_loss did not improve from 0.13702
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8681 - loss: 0.1492 - val_accuracy: 0.8750 - val_loss: 0.1418 - learning_rate: 0.0010
# Epoch 30/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8638 - loss: 0.1536
# Epoch 30: val_loss did not improve from 0.13702
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8638 - loss: 0.1536 - val_accuracy: 0.8779 - val_loss: 0.1388 - learning_rate: 0.0010
# Epoch 31/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8673 - loss: 0.1498
# Epoch 31: val_loss did not improve from 0.13702
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8673 - loss: 0.1498 - val_accuracy: 0.8750 - val_loss: 0.1393 - learning_rate: 0.0010
# Epoch 32/250
#  995/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8694 - loss: 0.1467
# Epoch 32: val_loss did not improve from 0.13702
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8694 - loss: 0.1467 - val_accuracy: 0.8762 - val_loss: 0.1421 - learning_rate: 0.0010
# Epoch 33/250
#  999/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8699 - loss: 0.1465
# Epoch 33: val_loss improved from 0.13702 to 0.13615, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8699 - loss: 0.1465 - val_accuracy: 0.8799 - val_loss: 0.1362 - learning_rate: 0.0010
# Epoch 34/250
#  998/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8686 - loss: 0.1482
# Epoch 34: val_loss did not improve from 0.13615
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8686 - loss: 0.1482 - val_accuracy: 0.8564 - val_loss: 0.1589 - learning_rate: 0.0010
# Epoch 35/250
#  999/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8695 - loss: 0.1466
# Epoch 35: val_loss improved from 0.13615 to 0.13525, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8695 - loss: 0.1466 - val_accuracy: 0.8766 - val_loss: 0.1353 - learning_rate: 0.0010
# Epoch 36/250
#  998/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8703 - loss: 0.1466
# Epoch 36: val_loss improved from 0.13525 to 0.13387, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8703 - loss: 0.1466 - val_accuracy: 0.8849 - val_loss: 0.1339 - learning_rate: 0.0010
# Epoch 37/250
#  994/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8691 - loss: 0.1483
# Epoch 37: val_loss did not improve from 0.13387
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8691 - loss: 0.1483 - val_accuracy: 0.8666 - val_loss: 0.1573 - learning_rate: 0.0010
# Epoch 38/250
#  998/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8705 - loss: 0.1464
# Epoch 38: val_loss did not improve from 0.13387
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8705 - loss: 0.1464 - val_accuracy: 0.8738 - val_loss: 0.1420 - learning_rate: 0.0010
# Epoch 39/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8690 - loss: 0.1474
# Epoch 39: val_loss did not improve from 0.13387
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8690 - loss: 0.1474 - val_accuracy: 0.8769 - val_loss: 0.1397 - learning_rate: 0.0010
# Epoch 40/250
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8669 - loss: 0.1501
# Epoch 40: val_loss did not improve from 0.13387
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8669 - loss: 0.1501 - val_accuracy: 0.8528 - val_loss: 0.1669 - learning_rate: 0.0010
# Epoch 41/250
#  995/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8605 - loss: 0.1570
# Epoch 41: val_loss did not improve from 0.13387
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8605 - loss: 0.1569 - val_accuracy: 0.8774 - val_loss: 0.1420 - learning_rate: 0.0010
# Epoch 42/250
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8696 - loss: 0.1467
# Epoch 42: val_loss did not improve from 0.13387
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8696 - loss: 0.1467 - val_accuracy: 0.8804 - val_loss: 0.1370 - learning_rate: 0.0010
# Epoch 43/250
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8607 - loss: 0.1580
# Epoch 43: val_loss did not improve from 0.13387
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8607 - loss: 0.1580 - val_accuracy: 0.8710 - val_loss: 0.1469 - learning_rate: 0.0010
# Epoch 44/250
#  999/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8682 - loss: 0.1483
# Epoch 44: val_loss did not improve from 0.13387
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8682 - loss: 0.1483 - val_accuracy: 0.8786 - val_loss: 0.1361 - learning_rate: 0.0010
# Epoch 45/250
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8692 - loss: 0.1473
# Epoch 45: val_loss did not improve from 0.13387
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8692 - loss: 0.1473 - val_accuracy: 0.8687 - val_loss: 0.1520 - learning_rate: 0.0010
# Epoch 46/250
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8679 - loss: 0.1499
# Epoch 46: val_loss did not improve from 0.13387
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8679 - loss: 0.1499 - val_accuracy: 0.8526 - val_loss: 0.1652 - learning_rate: 0.0010
# Epoch 47/250
#  994/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8774 - loss: 0.1375
# Epoch 47: val_loss improved from 0.13387 to 0.12710, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8774 - loss: 0.1375 - val_accuracy: 0.8861 - val_loss: 0.1271 - learning_rate: 5.0000e-04
# Epoch 48/250
#  999/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8811 - loss: 0.1313
# Epoch 48: val_loss improved from 0.12710 to 0.12301, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8811 - loss: 0.1313 - val_accuracy: 0.8883 - val_loss: 0.1230 - learning_rate: 5.0000e-04
# Epoch 49/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8793 - loss: 0.1333
# Epoch 49: val_loss improved from 0.12301 to 0.12194, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8793 - loss: 0.1333 - val_accuracy: 0.8910 - val_loss: 0.1219 - learning_rate: 5.0000e-04
# Epoch 50/250
#  995/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8836 - loss: 0.1271
# Epoch 50: val_loss did not improve from 0.12194
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8835 - loss: 0.1271 - val_accuracy: 0.8816 - val_loss: 0.1264 - learning_rate: 5.0000e-04
# Epoch 51/250
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8835 - loss: 0.1269
# Epoch 51: val_loss did not improve from 0.12194
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8835 - loss: 0.1269 - val_accuracy: 0.8695 - val_loss: 0.1436 - learning_rate: 5.0000e-04
# Epoch 52/250
#  999/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8804 - loss: 0.1326
# Epoch 52: val_loss improved from 0.12194 to 0.12039, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8804 - loss: 0.1326 - val_accuracy: 0.8891 - val_loss: 0.1204 - learning_rate: 5.0000e-04
# Epoch 53/250
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8837 - loss: 0.1265
# Epoch 53: val_loss did not improve from 0.12039
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8837 - loss: 0.1265 - val_accuracy: 0.8883 - val_loss: 0.1212 - learning_rate: 5.0000e-04
# Epoch 54/250
#  996/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8793 - loss: 0.1325
# Epoch 54: val_loss improved from 0.12039 to 0.11978, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8793 - loss: 0.1325 - val_accuracy: 0.8910 - val_loss: 0.1198 - learning_rate: 5.0000e-04
# Epoch 55/250
#  997/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8849 - loss: 0.1265
# Epoch 55: val_loss improved from 0.11978 to 0.11893, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8849 - loss: 0.1265 - val_accuracy: 0.8905 - val_loss: 0.1189 - learning_rate: 5.0000e-04
# Epoch 56/250
#  998/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8838 - loss: 0.1266
# Epoch 56: val_loss did not improve from 0.11893
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8838 - loss: 0.1266 - val_accuracy: 0.8851 - val_loss: 0.1235 - learning_rate: 5.0000e-04
# Epoch 57/250
#  994/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8831 - loss: 0.1274
# Epoch 57: val_loss did not improve from 0.11893
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8831 - loss: 0.1274 - val_accuracy: 0.8870 - val_loss: 0.1228 - learning_rate: 5.0000e-04
# Epoch 58/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8844 - loss: 0.1258
# Epoch 58: val_loss improved from 0.11893 to 0.11847, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8844 - loss: 0.1258 - val_accuracy: 0.8902 - val_loss: 0.1185 - learning_rate: 5.0000e-04
# Epoch 59/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8850 - loss: 0.1256
# Epoch 59: val_loss did not improve from 0.11847
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8850 - loss: 0.1256 - val_accuracy: 0.8878 - val_loss: 0.1208 - learning_rate: 5.0000e-04
# Epoch 60/250
#  996/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8811 - loss: 0.1303
# Epoch 60: val_loss did not improve from 0.11847
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8811 - loss: 0.1303 - val_accuracy: 0.8900 - val_loss: 0.1202 - learning_rate: 5.0000e-04
# Epoch 61/250
#  994/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8798 - loss: 0.1325
# Epoch 61: val_loss did not improve from 0.11847
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8798 - loss: 0.1325 - val_accuracy: 0.8688 - val_loss: 0.1385 - learning_rate: 5.0000e-04
# Epoch 62/250
#  998/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8816 - loss: 0.1289
# Epoch 62: val_loss did not improve from 0.11847
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8816 - loss: 0.1289 - val_accuracy: 0.8890 - val_loss: 0.1198 - learning_rate: 5.0000e-04
# Epoch 63/250
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8801 - loss: 0.1321
# Epoch 63: val_loss improved from 0.11847 to 0.11839, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8801 - loss: 0.1321 - val_accuracy: 0.8923 - val_loss: 0.1184 - learning_rate: 5.0000e-04
# Epoch 64/250
#  999/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8787 - loss: 0.1347
# Epoch 64: val_loss did not improve from 0.11839
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8787 - loss: 0.1347 - val_accuracy: 0.8921 - val_loss: 0.1194 - learning_rate: 5.0000e-04
# Epoch 65/250
#  997/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8832 - loss: 0.1281
# Epoch 65: val_loss did not improve from 0.11839
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8832 - loss: 0.1281 - val_accuracy: 0.8643 - val_loss: 0.1618 - learning_rate: 5.0000e-04
# Epoch 66/250
#  997/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8681 - loss: 0.1493
# Epoch 66: val_loss did not improve from 0.11839
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8682 - loss: 0.1492 - val_accuracy: 0.8887 - val_loss: 0.1245 - learning_rate: 5.0000e-04
# Epoch 67/250
#  996/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8814 - loss: 0.1303
# Epoch 67: val_loss did not improve from 0.11839
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8814 - loss: 0.1303 - val_accuracy: 0.8817 - val_loss: 0.1285 - learning_rate: 5.0000e-04
# Epoch 68/250
#  997/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8845 - loss: 0.1256
# Epoch 68: val_loss did not improve from 0.11839
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8845 - loss: 0.1256 - val_accuracy: 0.8895 - val_loss: 0.1192 - learning_rate: 5.0000e-04
# Epoch 69/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8899 - loss: 0.1182
# Epoch 69: val_loss improved from 0.11839 to 0.11424, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8899 - loss: 0.1182 - val_accuracy: 0.8961 - val_loss: 0.1142 - learning_rate: 2.5000e-04
# Epoch 70/250
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8904 - loss: 0.1171
# Epoch 70: val_loss improved from 0.11424 to 0.11380, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8904 - loss: 0.1171 - val_accuracy: 0.8945 - val_loss: 0.1138 - learning_rate: 2.5000e-04
# Epoch 71/250
#  997/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8865 - loss: 0.1241
# Epoch 71: val_loss did not improve from 0.11380
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8864 - loss: 0.1242 - val_accuracy: 0.8916 - val_loss: 0.1165 - learning_rate: 2.5000e-04
# Epoch 72/250
#  994/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8871 - loss: 0.1233
# Epoch 72: val_loss did not improve from 0.11380
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8871 - loss: 0.1232 - val_accuracy: 0.8951 - val_loss: 0.1138 - learning_rate: 2.5000e-04
# Epoch 73/250
#  999/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8903 - loss: 0.1175
# Epoch 73: val_loss did not improve from 0.11380
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8903 - loss: 0.1175 - val_accuracy: 0.8917 - val_loss: 0.1144 - learning_rate: 2.5000e-04
# Epoch 74/250
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8896 - loss: 0.1181
# Epoch 74: val_loss improved from 0.11380 to 0.11262, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8896 - loss: 0.1181 - val_accuracy: 0.8976 - val_loss: 0.1126 - learning_rate: 2.5000e-04
# Epoch 75/250
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8908 - loss: 0.1173
# Epoch 75: val_loss improved from 0.11262 to 0.11252, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8908 - loss: 0.1173 - val_accuracy: 0.8973 - val_loss: 0.1125 - learning_rate: 2.5000e-04
# Epoch 76/250
#  996/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8913 - loss: 0.1160
# Epoch 76: val_loss did not improve from 0.11252
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8913 - loss: 0.1160 - val_accuracy: 0.8939 - val_loss: 0.1143 - learning_rate: 2.5000e-04
# Epoch 77/250
#  995/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8894 - loss: 0.1181
# Epoch 77: val_loss did not improve from 0.11252
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8894 - loss: 0.1181 - val_accuracy: 0.8974 - val_loss: 0.1126 - learning_rate: 2.5000e-04
# Epoch 78/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8912 - loss: 0.1162
# Epoch 78: val_loss did not improve from 0.11252
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8912 - loss: 0.1162 - val_accuracy: 0.8923 - val_loss: 0.1145 - learning_rate: 2.5000e-04
# Epoch 79/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8916 - loss: 0.1153
# Epoch 79: val_loss did not improve from 0.11252
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8916 - loss: 0.1153 - val_accuracy: 0.8923 - val_loss: 0.1139 - learning_rate: 2.5000e-04
# Epoch 80/250
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8911 - loss: 0.1160
# Epoch 80: val_loss improved from 0.11252 to 0.11222, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8911 - loss: 0.1160 - val_accuracy: 0.8947 - val_loss: 0.1122 - learning_rate: 2.5000e-04
# Epoch 81/250
#  995/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8910 - loss: 0.1161
# Epoch 81: val_loss did not improve from 0.11222
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8910 - loss: 0.1161 - val_accuracy: 0.8961 - val_loss: 0.1123 - learning_rate: 2.5000e-04
# Epoch 82/250
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8918 - loss: 0.1162
# Epoch 82: val_loss did not improve from 0.11222
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8918 - loss: 0.1162 - val_accuracy: 0.8960 - val_loss: 0.1130 - learning_rate: 2.5000e-04
# Epoch 83/250
#  996/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8909 - loss: 0.1166
# Epoch 83: val_loss did not improve from 0.11222
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8909 - loss: 0.1166 - val_accuracy: 0.8948 - val_loss: 0.1132 - learning_rate: 2.5000e-04
# Epoch 84/250
#  994/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8906 - loss: 0.1168
# Epoch 84: val_loss did not improve from 0.11222
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8906 - loss: 0.1168 - val_accuracy: 0.8963 - val_loss: 0.1126 - learning_rate: 2.5000e-04
# Epoch 85/250
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8906 - loss: 0.1171
# Epoch 85: val_loss improved from 0.11222 to 0.11170, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8906 - loss: 0.1171 - val_accuracy: 0.8972 - val_loss: 0.1117 - learning_rate: 2.5000e-04
# Epoch 86/250
#  994/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8919 - loss: 0.1154
# Epoch 86: val_loss did not improve from 0.11170
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8919 - loss: 0.1154 - val_accuracy: 0.8942 - val_loss: 0.1126 - learning_rate: 2.5000e-04
# Epoch 87/250
#  997/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8915 - loss: 0.1157
# Epoch 87: val_loss did not improve from 0.11170
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8914 - loss: 0.1157 - val_accuracy: 0.8946 - val_loss: 0.1129 - learning_rate: 2.5000e-04
# Epoch 88/250
#  994/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8911 - loss: 0.1161
# Epoch 88: val_loss did not improve from 0.11170
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8911 - loss: 0.1161 - val_accuracy: 0.8953 - val_loss: 0.1121 - learning_rate: 2.5000e-04
# Epoch 89/250
#  999/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8912 - loss: 0.1158
# Epoch 89: val_loss improved from 0.11170 to 0.11160, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8912 - loss: 0.1158 - val_accuracy: 0.8976 - val_loss: 0.1116 - learning_rate: 2.5000e-04
# Epoch 90/250
#  999/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8914 - loss: 0.1155
# Epoch 90: val_loss did not improve from 0.11160
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8914 - loss: 0.1155 - val_accuracy: 0.8968 - val_loss: 0.1123 - learning_rate: 2.5000e-04
# Epoch 91/250
#  994/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8903 - loss: 0.1177
# Epoch 91: val_loss did not improve from 0.11160
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8903 - loss: 0.1177 - val_accuracy: 0.8927 - val_loss: 0.1186 - learning_rate: 2.5000e-04
# Epoch 92/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8903 - loss: 0.1174
# Epoch 92: val_loss did not improve from 0.11160
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8903 - loss: 0.1174 - val_accuracy: 0.8975 - val_loss: 0.1121 - learning_rate: 2.5000e-04
# Epoch 93/250
#  994/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8926 - loss: 0.1148
# Epoch 93: val_loss did not improve from 0.11160
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8926 - loss: 0.1148 - val_accuracy: 0.8943 - val_loss: 0.1129 - learning_rate: 2.5000e-04
# Epoch 94/250
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8918 - loss: 0.1154
# Epoch 94: val_loss did not improve from 0.11160
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8918 - loss: 0.1154 - val_accuracy: 0.8929 - val_loss: 0.1143 - learning_rate: 2.5000e-04
# Epoch 95/250
#  997/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8912 - loss: 0.1156
# Epoch 95: val_loss did not improve from 0.11160
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8912 - loss: 0.1156 - val_accuracy: 0.8962 - val_loss: 0.1127 - learning_rate: 2.5000e-04
# Epoch 96/250
#  999/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8944 - loss: 0.1127
# Epoch 96: val_loss improved from 0.11160 to 0.11047, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8944 - loss: 0.1127 - val_accuracy: 0.8991 - val_loss: 0.1105 - learning_rate: 1.2500e-04
# Epoch 97/250
#  999/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8944 - loss: 0.1126
# Epoch 97: val_loss improved from 0.11047 to 0.11024, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8944 - loss: 0.1126 - val_accuracy: 0.8988 - val_loss: 0.1102 - learning_rate: 1.2500e-04
# Epoch 98/250
#  994/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8946 - loss: 0.1124
# Epoch 98: val_loss improved from 0.11024 to 0.11023, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8946 - loss: 0.1124 - val_accuracy: 0.8978 - val_loss: 0.1102 - learning_rate: 1.2500e-04
# Epoch 99/250
#  999/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8943 - loss: 0.1127
# Epoch 99: val_loss did not improve from 0.11023
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8943 - loss: 0.1127 - val_accuracy: 0.8989 - val_loss: 0.1105 - learning_rate: 1.2500e-04
# Epoch 100/250
#  998/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8939 - loss: 0.1129
# Epoch 100: val_loss improved from 0.11023 to 0.11014, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8939 - loss: 0.1129 - val_accuracy: 0.8987 - val_loss: 0.1101 - learning_rate: 1.2500e-04
# Epoch 101/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8945 - loss: 0.1124
# Epoch 101: val_loss did not improve from 0.11014
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8945 - loss: 0.1124 - val_accuracy: 0.8973 - val_loss: 0.1104 - learning_rate: 1.2500e-04
# Epoch 102/250
#  997/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8937 - loss: 0.1134
# Epoch 102: val_loss improved from 0.11014 to 0.10991, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8937 - loss: 0.1134 - val_accuracy: 0.8998 - val_loss: 0.1099 - learning_rate: 1.2500e-04
# Epoch 103/250
#  996/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8944 - loss: 0.1125
# Epoch 103: val_loss improved from 0.10991 to 0.10978, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8944 - loss: 0.1125 - val_accuracy: 0.8996 - val_loss: 0.1098 - learning_rate: 1.2500e-04
# Epoch 104/250
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8946 - loss: 0.1122
# Epoch 104: val_loss did not improve from 0.10978
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8946 - loss: 0.1122 - val_accuracy: 0.8978 - val_loss: 0.1103 - learning_rate: 1.2500e-04
# Epoch 105/250
#  995/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8943 - loss: 0.1123
# Epoch 105: val_loss did not improve from 0.10978
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8943 - loss: 0.1123 - val_accuracy: 0.8959 - val_loss: 0.1107 - learning_rate: 1.2500e-04
# Epoch 106/250
#  995/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8940 - loss: 0.1125
# Epoch 106: val_loss did not improve from 0.10978
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8940 - loss: 0.1125 - val_accuracy: 0.8941 - val_loss: 0.1115 - learning_rate: 1.2500e-04
# Epoch 107/250
#  998/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8945 - loss: 0.1122
# Epoch 107: val_loss did not improve from 0.10978
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8945 - loss: 0.1122 - val_accuracy: 0.8941 - val_loss: 0.1126 - learning_rate: 1.2500e-04
# Epoch 108/250
#  995/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8948 - loss: 0.1125
# Epoch 108: val_loss did not improve from 0.10978
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8948 - loss: 0.1125 - val_accuracy: 0.8989 - val_loss: 0.1101 - learning_rate: 1.2500e-04
# Epoch 109/250
#  997/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8946 - loss: 0.1123
# Epoch 109: val_loss did not improve from 0.10978
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8946 - loss: 0.1123 - val_accuracy: 0.8976 - val_loss: 0.1109 - learning_rate: 1.2500e-04
# Epoch 110/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8949 - loss: 0.1119
# Epoch 110: val_loss did not improve from 0.10978
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8949 - loss: 0.1119 - val_accuracy: 0.8945 - val_loss: 0.1121 - learning_rate: 1.2500e-04
# Epoch 111/250
#  995/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8949 - loss: 0.1122
# Epoch 111: val_loss improved from 0.10978 to 0.10972, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8949 - loss: 0.1122 - val_accuracy: 0.8988 - val_loss: 0.1097 - learning_rate: 1.2500e-04
# Epoch 112/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8950 - loss: 0.1121
# Epoch 112: val_loss did not improve from 0.10972
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8950 - loss: 0.1121 - val_accuracy: 0.8950 - val_loss: 0.1117 - learning_rate: 1.2500e-04
# Epoch 113/250
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8952 - loss: 0.1115
# Epoch 113: val_loss did not improve from 0.10972
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8952 - loss: 0.1115 - val_accuracy: 0.8984 - val_loss: 0.1099 - learning_rate: 1.2500e-04
# Epoch 114/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8966 - loss: 0.1107
# Epoch 114: val_loss improved from 0.10972 to 0.10882, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8966 - loss: 0.1107 - val_accuracy: 0.9003 - val_loss: 0.1088 - learning_rate: 6.2500e-05
# Epoch 115/250
#  999/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8968 - loss: 0.1107
# Epoch 115: val_loss did not improve from 0.10882
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8968 - loss: 0.1107 - val_accuracy: 0.9004 - val_loss: 0.1089 - learning_rate: 6.2500e-05
# Epoch 116/250
#  997/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8963 - loss: 0.1107
# Epoch 116: val_loss improved from 0.10882 to 0.10877, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8963 - loss: 0.1107 - val_accuracy: 0.8995 - val_loss: 0.1088 - learning_rate: 6.2500e-05
# Epoch 117/250
#  998/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8965 - loss: 0.1107
# Epoch 117: val_loss improved from 0.10877 to 0.10863, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8965 - loss: 0.1107 - val_accuracy: 0.9007 - val_loss: 0.1086 - learning_rate: 6.2500e-05
# Epoch 118/250
#  997/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8969 - loss: 0.1103
# Epoch 118: val_loss did not improve from 0.10863
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8969 - loss: 0.1103 - val_accuracy: 0.9011 - val_loss: 0.1090 - learning_rate: 6.2500e-05
# Epoch 119/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8968 - loss: 0.1104
# Epoch 119: val_loss improved from 0.10863 to 0.10851, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8968 - loss: 0.1104 - val_accuracy: 0.9012 - val_loss: 0.1085 - learning_rate: 6.2500e-05
# Epoch 120/250
#  995/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8965 - loss: 0.1105
# Epoch 120: val_loss improved from 0.10851 to 0.10850, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8965 - loss: 0.1105 - val_accuracy: 0.8994 - val_loss: 0.1085 - learning_rate: 6.2500e-05
# Epoch 121/250
#  997/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8965 - loss: 0.1106
# Epoch 121: val_loss did not improve from 0.10850
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8965 - loss: 0.1106 - val_accuracy: 0.8972 - val_loss: 0.1104 - learning_rate: 6.2500e-05
# Epoch 122/250
#  998/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8967 - loss: 0.1104
# Epoch 122: val_loss improved from 0.10850 to 0.10821, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8967 - loss: 0.1104 - val_accuracy: 0.9019 - val_loss: 0.1082 - learning_rate: 6.2500e-05
# Epoch 123/250
#  996/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8970 - loss: 0.1101
# Epoch 123: val_loss improved from 0.10821 to 0.10810, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8970 - loss: 0.1101 - val_accuracy: 0.9013 - val_loss: 0.1081 - learning_rate: 6.2500e-05
# Epoch 124/250
#  997/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8973 - loss: 0.1099
# Epoch 124: val_loss did not improve from 0.10810
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8973 - loss: 0.1099 - val_accuracy: 0.9012 - val_loss: 0.1085 - learning_rate: 6.2500e-05
# Epoch 125/250
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8964 - loss: 0.1105
# Epoch 125: val_loss did not improve from 0.10810
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8964 - loss: 0.1105 - val_accuracy: 0.9011 - val_loss: 0.1082 - learning_rate: 6.2500e-05
# Epoch 126/250
#  995/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8969 - loss: 0.1103
# Epoch 126: val_loss did not improve from 0.10810
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8969 - loss: 0.1103 - val_accuracy: 0.8989 - val_loss: 0.1084 - learning_rate: 6.2500e-05
# Epoch 127/250
#  997/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8971 - loss: 0.1098
# Epoch 127: val_loss did not improve from 0.10810
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8971 - loss: 0.1098 - val_accuracy: 0.9017 - val_loss: 0.1086 - learning_rate: 6.2500e-05
# Epoch 128/250
#  994/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8976 - loss: 0.1099
# Epoch 128: val_loss improved from 0.10810 to 0.10797, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8976 - loss: 0.1099 - val_accuracy: 0.9008 - val_loss: 0.1080 - learning_rate: 6.2500e-05
# Epoch 129/250
#  996/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8970 - loss: 0.1102
# Epoch 129: val_loss improved from 0.10797 to 0.10794, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8970 - loss: 0.1102 - val_accuracy: 0.9012 - val_loss: 0.1079 - learning_rate: 6.2500e-05
# Epoch 130/250
#  995/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8973 - loss: 0.1101
# Epoch 130: val_loss did not improve from 0.10794
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8973 - loss: 0.1101 - val_accuracy: 0.9018 - val_loss: 0.1080 - learning_rate: 6.2500e-05
# Epoch 131/250
#  997/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8973 - loss: 0.1102
# Epoch 131: val_loss improved from 0.10794 to 0.10790, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8973 - loss: 0.1102 - val_accuracy: 0.9015 - val_loss: 0.1079 - learning_rate: 6.2500e-05
# Epoch 132/250
#  997/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8972 - loss: 0.1101
# Epoch 132: val_loss improved from 0.10790 to 0.10789, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8972 - loss: 0.1101 - val_accuracy: 0.9013 - val_loss: 0.1079 - learning_rate: 6.2500e-05
# Epoch 133/250
#  993/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8969 - loss: 0.1100
# Epoch 133: val_loss improved from 0.10789 to 0.10766, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8969 - loss: 0.1100 - val_accuracy: 0.9021 - val_loss: 0.1077 - learning_rate: 6.2500e-05
# Epoch 134/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8973 - loss: 0.1098
# Epoch 134: val_loss improved from 0.10766 to 0.10759, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8973 - loss: 0.1098 - val_accuracy: 0.9025 - val_loss: 0.1076 - learning_rate: 6.2500e-05
# Epoch 135/250
#  997/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8970 - loss: 0.1098
# Epoch 135: val_loss did not improve from 0.10759
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8970 - loss: 0.1098 - val_accuracy: 0.9012 - val_loss: 0.1079 - learning_rate: 6.2500e-05
# Epoch 136/250
#  997/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8974 - loss: 0.1097
# Epoch 136: val_loss did not improve from 0.10759
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8974 - loss: 0.1097 - val_accuracy: 0.9023 - val_loss: 0.1077 - learning_rate: 6.2500e-05
# Epoch 137/250
#  994/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8971 - loss: 0.1096
# Epoch 137: val_loss did not improve from 0.10759
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8971 - loss: 0.1096 - val_accuracy: 0.9019 - val_loss: 0.1079 - learning_rate: 6.2500e-05
# Epoch 138/250
#  998/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8973 - loss: 0.1099
# Epoch 138: val_loss did not improve from 0.10759
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8973 - loss: 0.1099 - val_accuracy: 0.9016 - val_loss: 0.1077 - learning_rate: 6.2500e-05
# Epoch 139/250
#  999/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8973 - loss: 0.1096
# Epoch 139: val_loss did not improve from 0.10759
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8973 - loss: 0.1096 - val_accuracy: 0.9006 - val_loss: 0.1085 - learning_rate: 6.2500e-05
# Epoch 140/250
#  995/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8973 - loss: 0.1097
# Epoch 140: val_loss improved from 0.10759 to 0.10755, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8973 - loss: 0.1097 - val_accuracy: 0.9025 - val_loss: 0.1075 - learning_rate: 6.2500e-05
# Epoch 141/250
#  996/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8976 - loss: 0.1097
# Epoch 141: val_loss did not improve from 0.10755
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8976 - loss: 0.1097 - val_accuracy: 0.9016 - val_loss: 0.1081 - learning_rate: 6.2500e-05
# Epoch 142/250
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8976 - loss: 0.1096
# Epoch 142: val_loss did not improve from 0.10755
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8976 - loss: 0.1096 - val_accuracy: 0.9019 - val_loss: 0.1078 - learning_rate: 6.2500e-05
# Epoch 143/250
#  997/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8970 - loss: 0.1101
# Epoch 143: val_loss did not improve from 0.10755
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8970 - loss: 0.1101 - val_accuracy: 0.9019 - val_loss: 0.1077 - learning_rate: 6.2500e-05
# Epoch 144/250
#  999/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8973 - loss: 0.1098
# Epoch 144: val_loss improved from 0.10755 to 0.10750, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8973 - loss: 0.1098 - val_accuracy: 0.9026 - val_loss: 0.1075 - learning_rate: 6.2500e-05
# Epoch 145/250
#  993/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8973 - loss: 0.1097
# Epoch 145: val_loss did not improve from 0.10750
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8973 - loss: 0.1097 - val_accuracy: 0.9010 - val_loss: 0.1084 - learning_rate: 6.2500e-05
# Epoch 146/250
#  998/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8977 - loss: 0.1096
# Epoch 146: val_loss improved from 0.10750 to 0.10736, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8977 - loss: 0.1096 - val_accuracy: 0.9027 - val_loss: 0.1074 - learning_rate: 6.2500e-05
# Epoch 147/250
#  996/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8974 - loss: 0.1095
# Epoch 147: val_loss did not improve from 0.10736
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8974 - loss: 0.1095 - val_accuracy: 0.8977 - val_loss: 0.1095 - learning_rate: 6.2500e-05
# Epoch 148/250
#  993/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8975 - loss: 0.1096
# Epoch 148: val_loss did not improve from 0.10736
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8975 - loss: 0.1096 - val_accuracy: 0.8993 - val_loss: 0.1086 - learning_rate: 6.2500e-05
# Epoch 149/250
#  999/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8975 - loss: 0.1096
# Epoch 149: val_loss did not improve from 0.10736
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8975 - loss: 0.1096 - val_accuracy: 0.9009 - val_loss: 0.1086 - learning_rate: 6.2500e-05
# Epoch 150/250
#  998/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8976 - loss: 0.1094
# Epoch 150: val_loss did not improve from 0.10736
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8976 - loss: 0.1094 - val_accuracy: 0.9021 - val_loss: 0.1078 - learning_rate: 6.2500e-05
# Epoch 151/250
#  999/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8981 - loss: 0.1093
# Epoch 151: val_loss did not improve from 0.10736
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8981 - loss: 0.1093 - val_accuracy: 0.9007 - val_loss: 0.1082 - learning_rate: 6.2500e-05
# Epoch 152/250
#  999/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8974 - loss: 0.1098
# Epoch 152: val_loss did not improve from 0.10736
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8974 - loss: 0.1098 - val_accuracy: 0.9019 - val_loss: 0.1078 - learning_rate: 6.2500e-05
# Epoch 153/250
#  996/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8985 - loss: 0.1092
# Epoch 153: val_loss improved from 0.10736 to 0.10719, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8985 - loss: 0.1092 - val_accuracy: 0.9026 - val_loss: 0.1072 - learning_rate: 6.2500e-05
# Epoch 154/250
#  999/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8982 - loss: 0.1094
# Epoch 154: val_loss did not improve from 0.10719
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8982 - loss: 0.1094 - val_accuracy: 0.9032 - val_loss: 0.1072 - learning_rate: 6.2500e-05
# Epoch 155/250
#  997/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8979 - loss: 0.1095
# Epoch 155: val_loss did not improve from 0.10719
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8979 - loss: 0.1095 - val_accuracy: 0.9026 - val_loss: 0.1075 - learning_rate: 6.2500e-05
# Epoch 156/250
#  998/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8974 - loss: 0.1097
# Epoch 156: val_loss improved from 0.10719 to 0.10714, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8974 - loss: 0.1097 - val_accuracy: 0.9016 - val_loss: 0.1071 - learning_rate: 6.2500e-05
# Epoch 157/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8978 - loss: 0.1094
# Epoch 157: val_loss did not improve from 0.10714
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8978 - loss: 0.1094 - val_accuracy: 0.9020 - val_loss: 0.1076 - learning_rate: 6.2500e-05
# Epoch 158/250
#  997/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8979 - loss: 0.1092
# Epoch 158: val_loss did not improve from 0.10714
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8979 - loss: 0.1092 - val_accuracy: 0.9030 - val_loss: 0.1073 - learning_rate: 6.2500e-05
# Epoch 159/250
#  995/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8974 - loss: 0.1096
# Epoch 159: val_loss did not improve from 0.10714
# ...
# Epoch 198/250
#  995/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9003 - loss: 0.1075
# Epoch 198: val_loss improved from 0.10522 to 0.10510, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9003 - loss: 0.1075 - val_accuracy: 0.9058 - val_loss: 0.1051 - learning_rate: 3.1250e-05
# Epoch 199/250
#  999/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9005 - loss: 0.1074
# Epoch 199: val_loss did not improve from 0.10510
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9005 - loss: 0.1074 - val_accuracy: 0.9050 - val_loss: 0.1052 - learning_rate: 3.1250e-05
# Epoch 200/250
#  999/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9005 - loss: 0.1074
# Epoch 200: val_loss did not improve from 0.10510
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9005 - loss: 0.1074 - val_accuracy: 0.9053 - val_loss: 0.1052 - learning_rate: 3.1250e-05
# Epoch 201/250
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9003 - loss: 0.1073
# Epoch 201: val_loss did not improve from 0.10510
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9003 - loss: 0.1073 - val_accuracy: 0.9022 - val_loss: 0.1066 - learning_rate: 3.1250e-05
# Epoch 202/250
#  995/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9003 - loss: 0.1072
# Epoch 202: val_loss did not improve from 0.10510
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9003 - loss: 0.1072 - val_accuracy: 0.9053 - val_loss: 0.1052 - learning_rate: 3.1250e-05
# Epoch 203/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8998 - loss: 0.1073
# Epoch 203: val_loss did not improve from 0.10510
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8998 - loss: 0.1073 - val_accuracy: 0.9048 - val_loss: 0.1052 - learning_rate: 3.1250e-05
# Epoch 204/250
#  994/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9009 - loss: 0.1070
# Epoch 204: val_loss did not improve from 0.10510
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9009 - loss: 0.1070 - val_accuracy: 0.9048 - val_loss: 0.1051 - learning_rate: 3.1250e-05
# Epoch 205/250
#  993/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9002 - loss: 0.1075
# Epoch 205: val_loss improved from 0.10510 to 0.10483, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9002 - loss: 0.1075 - val_accuracy: 0.9063 - val_loss: 0.1048 - learning_rate: 3.1250e-05
# Epoch 206/250
#  996/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9003 - loss: 0.1072
# Epoch 206: val_loss did not improve from 0.10483
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9003 - loss: 0.1072 - val_accuracy: 0.9054 - val_loss: 0.1049 - learning_rate: 3.1250e-05
# Epoch 207/250
#  995/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9005 - loss: 0.1073
# Epoch 207: val_loss improved from 0.10483 to 0.10477, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9005 - loss: 0.1073 - val_accuracy: 0.9056 - val_loss: 0.1048 - learning_rate: 3.1250e-05
# Epoch 208/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9002 - loss: 0.1071
# Epoch 208: val_loss did not improve from 0.10477
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9002 - loss: 0.1071 - val_accuracy: 0.9050 - val_loss: 0.1049 - learning_rate: 3.1250e-05
# Epoch 209/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9003 - loss: 0.1072
# Epoch 209: val_loss did not improve from 0.10477
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9003 - loss: 0.1072 - val_accuracy: 0.9050 - val_loss: 0.1052 - learning_rate: 3.1250e-05
# Epoch 210/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9005 - loss: 0.1072
# Epoch 210: val_loss did not improve from 0.10477
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9005 - loss: 0.1072 - val_accuracy: 0.9054 - val_loss: 0.1048 - learning_rate: 3.1250e-05
# Epoch 211/250
#  996/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9009 - loss: 0.1068
# Epoch 211: val_loss did not improve from 0.10477
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9009 - loss: 0.1068 - val_accuracy: 0.9052 - val_loss: 0.1049 - learning_rate: 3.1250e-05
# Epoch 212/250
#  996/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9006 - loss: 0.1071
# Epoch 212: val_loss improved from 0.10477 to 0.10470, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9006 - loss: 0.1071 - val_accuracy: 0.9056 - val_loss: 0.1047 - learning_rate: 3.1250e-05
# Epoch 213/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9001 - loss: 0.1074
# Epoch 213: val_loss improved from 0.10470 to 0.10455, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9001 - loss: 0.1074 - val_accuracy: 0.9057 - val_loss: 0.1046 - learning_rate: 3.1250e-05
# Epoch 214/250
#  999/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9012 - loss: 0.1067
# Epoch 214: val_loss did not improve from 0.10455
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9012 - loss: 0.1067 - val_accuracy: 0.9061 - val_loss: 0.1046 - learning_rate: 3.1250e-05
# Epoch 215/250
#  994/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9011 - loss: 0.1070
# Epoch 215: val_loss did not improve from 0.10455
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9011 - loss: 0.1070 - val_accuracy: 0.9042 - val_loss: 0.1053 - learning_rate: 3.1250e-05
# Epoch 216/250
#  994/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9008 - loss: 0.1069
# Epoch 216: val_loss did not improve from 0.10455
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9008 - loss: 0.1069 - val_accuracy: 0.9055 - val_loss: 0.1046 - learning_rate: 3.1250e-05
# Epoch 217/250
#  998/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9004 - loss: 0.1072
# Epoch 217: val_loss improved from 0.10455 to 0.10450, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9004 - loss: 0.1072 - val_accuracy: 0.9060 - val_loss: 0.1045 - learning_rate: 3.1250e-05
# Epoch 218/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9009 - loss: 0.1068
# Epoch 218: val_loss improved from 0.10450 to 0.10444, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9009 - loss: 0.1068 - val_accuracy: 0.9062 - val_loss: 0.1044 - learning_rate: 3.1250e-05
# Epoch 219/250
#  999/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9008 - loss: 0.1069
# Epoch 219: val_loss did not improve from 0.10444
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9008 - loss: 0.1069 - val_accuracy: 0.9056 - val_loss: 0.1044 - learning_rate: 3.1250e-05
# Epoch 220/250
#  997/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9006 - loss: 0.1071
# Epoch 220: val_loss did not improve from 0.10444
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9006 - loss: 0.1071 - val_accuracy: 0.9050 - val_loss: 0.1047 - learning_rate: 3.1250e-05
# Epoch 221/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9009 - loss: 0.1069
# Epoch 221: val_loss did not improve from 0.10444
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9009 - loss: 0.1069 - val_accuracy: 0.9041 - val_loss: 0.1054 - learning_rate: 3.1250e-05
# Epoch 222/250
#  998/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9011 - loss: 0.1068
# Epoch 222: val_loss did not improve from 0.10444
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9011 - loss: 0.1068 - val_accuracy: 0.9052 - val_loss: 0.1045 - learning_rate: 3.1250e-05
# Epoch 223/250
#  998/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9011 - loss: 0.1068
# Epoch 223: val_loss improved from 0.10444 to 0.10443, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9011 - loss: 0.1068 - val_accuracy: 0.9053 - val_loss: 0.1044 - learning_rate: 3.1250e-05
# Epoch 224/250
#  995/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9014 - loss: 0.1069
# Epoch 224: val_loss did not improve from 0.10443
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9014 - loss: 0.1069 - val_accuracy: 0.9052 - val_loss: 0.1045 - learning_rate: 3.1250e-05
# Epoch 225/250
#  996/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9011 - loss: 0.1069
# Epoch 225: val_loss did not improve from 0.10443
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9011 - loss: 0.1069 - val_accuracy: 0.9057 - val_loss: 0.1045 - learning_rate: 3.1250e-05
# Epoch 226/250
#  998/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9009 - loss: 0.1068
# Epoch 226: val_loss did not improve from 0.10443
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9009 - loss: 0.1068 - val_accuracy: 0.9045 - val_loss: 0.1049 - learning_rate: 3.1250e-05
# Epoch 227/250
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9013 - loss: 0.1067
# Epoch 227: val_loss improved from 0.10443 to 0.10428, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9013 - loss: 0.1067 - val_accuracy: 0.9060 - val_loss: 0.1043 - learning_rate: 3.1250e-05
# Epoch 228/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9007 - loss: 0.1069
# Epoch 228: val_loss did not improve from 0.10428
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9007 - loss: 0.1069 - val_accuracy: 0.9055 - val_loss: 0.1043 - learning_rate: 3.1250e-05
# Epoch 229/250
#  994/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9006 - loss: 0.1070
# Epoch 229: val_loss did not improve from 0.10428
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9006 - loss: 0.1070 - val_accuracy: 0.9048 - val_loss: 0.1046 - learning_rate: 3.1250e-05
# Epoch 230/250
#  999/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9009 - loss: 0.1068
# Epoch 230: val_loss improved from 0.10428 to 0.10415, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9009 - loss: 0.1068 - val_accuracy: 0.9058 - val_loss: 0.1042 - learning_rate: 3.1250e-05
# Epoch 231/250
#  997/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9016 - loss: 0.1065
# Epoch 231: val_loss improved from 0.10415 to 0.10404, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9016 - loss: 0.1065 - val_accuracy: 0.9059 - val_loss: 0.1040 - learning_rate: 3.1250e-05
# Epoch 232/250
#  996/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9011 - loss: 0.1067
# Epoch 232: val_loss did not improve from 0.10404
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9011 - loss: 0.1067 - val_accuracy: 0.9059 - val_loss: 0.1041 - learning_rate: 3.1250e-05
# Epoch 233/250
#  998/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9013 - loss: 0.1066
# Epoch 233: val_loss did not improve from 0.10404
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9013 - loss: 0.1066 - val_accuracy: 0.9043 - val_loss: 0.1050 - learning_rate: 3.1250e-05
# Epoch 234/250
#  998/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9013 - loss: 0.1065
# Epoch 234: val_loss did not improve from 0.10404
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9013 - loss: 0.1065 - val_accuracy: 0.9061 - val_loss: 0.1041 - learning_rate: 3.1250e-05
# Epoch 235/250
#  999/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9014 - loss: 0.1063
# Epoch 235: val_loss did not improve from 0.10404
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9014 - loss: 0.1063 - val_accuracy: 0.9061 - val_loss: 0.1041 - learning_rate: 3.1250e-05
# Epoch 236/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9013 - loss: 0.1066
# Epoch 236: val_loss did not improve from 0.10404
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9013 - loss: 0.1066 - val_accuracy: 0.9053 - val_loss: 0.1043 - learning_rate: 3.1250e-05
# Epoch 237/250
#  994/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9009 - loss: 0.1066
# Epoch 237: val_loss did not improve from 0.10404
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9009 - loss: 0.1066 - val_accuracy: 0.9058 - val_loss: 0.1040 - learning_rate: 3.1250e-05
# Epoch 238/250
#  998/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9008 - loss: 0.1067
# Epoch 238: val_loss did not improve from 0.10404
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9008 - loss: 0.1067 - val_accuracy: 0.9056 - val_loss: 0.1043 - learning_rate: 3.1250e-05
# Epoch 239/250
#  998/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9009 - loss: 0.1067
# Epoch 239: val_loss did not improve from 0.10404
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9009 - loss: 0.1067 - val_accuracy: 0.9063 - val_loss: 0.1040 - learning_rate: 3.1250e-05
# Epoch 240/250
#  993/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9014 - loss: 0.1066
# Epoch 240: val_loss did not improve from 0.10404
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9014 - loss: 0.1066 - val_accuracy: 0.9041 - val_loss: 0.1048 - learning_rate: 3.1250e-05
# Epoch 241/250
#  998/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9013 - loss: 0.1062
# Epoch 241: val_loss did not improve from 0.10404
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9013 - loss: 0.1062 - val_accuracy: 0.9053 - val_loss: 0.1042 - learning_rate: 3.1250e-05
# Epoch 242/250
#  997/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9023 - loss: 0.1057
# Epoch 242: val_loss improved from 0.10404 to 0.10356, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9023 - loss: 0.1057 - val_accuracy: 0.9064 - val_loss: 0.1036 - learning_rate: 1.5625e-05
# Epoch 243/250
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9018 - loss: 0.1059
# Epoch 243: val_loss did not improve from 0.10356
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9018 - loss: 0.1059 - val_accuracy: 0.9065 - val_loss: 0.1037 - learning_rate: 1.5625e-05
# Epoch 244/250
#  999/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9026 - loss: 0.1056
# Epoch 244: val_loss did not improve from 0.10356
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9026 - loss: 0.1056 - val_accuracy: 0.9062 - val_loss: 0.1040 - learning_rate: 1.5625e-05
# Epoch 245/250
# 1000/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9021 - loss: 0.1059
# Epoch 245: val_loss improved from 0.10356 to 0.10353, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9021 - loss: 0.1059 - val_accuracy: 0.9067 - val_loss: 0.1035 - learning_rate: 1.5625e-05
# Epoch 246/250
#  998/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9028 - loss: 0.1056
# Epoch 246: val_loss did not improve from 0.10353
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9028 - loss: 0.1056 - val_accuracy: 0.9066 - val_loss: 0.1035 - learning_rate: 1.5625e-05
# Epoch 247/250
#  994/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9020 - loss: 0.1059
# Epoch 247: val_loss improved from 0.10353 to 0.10343, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9020 - loss: 0.1059 - val_accuracy: 0.9066 - val_loss: 0.1034 - learning_rate: 1.5625e-05
# Epoch 248/250
#  994/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9022 - loss: 0.1058
# Epoch 248: val_loss did not improve from 0.10343
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9022 - loss: 0.1058 - val_accuracy: 0.9065 - val_loss: 0.1035 - learning_rate: 1.5625e-05
# Epoch 249/250
#  998/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9024 - loss: 0.1057
# Epoch 249: val_loss improved from 0.10343 to 0.10336, saving model to best_model.weights.h5
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9024 - loss: 0.1057 - val_accuracy: 0.9068 - val_loss: 0.1034 - learning_rate: 1.5625e-05
# Epoch 250/250
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9023 - loss: 0.1056
# Epoch 250: val_loss did not improve from 0.10336
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9023 - loss: 0.1056 - val_accuracy: 0.9067 - val_loss: 0.1034 - learning_rate: 1.5625e-05

# %%
attack_FCN_no_time.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_40 (Dense)                │ (None, 448)            │        44,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_normalization_26          │ (None, 448)            │           896 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_28 (Dropout)            │ (None, 448)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_41 (Dense)                │ (None, 128)            │        57,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_normalization_27          │ (None, 128)            │           256 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_42 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_normalization_28          │ (None, 128)            │           256 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_29 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_43 (Dense)                │ (None, 192)            │        24,768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_normalization_29          │ (None, 192)            │           384 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_44 (Dense)                │ (None, 12)             │         2,316 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 441,638 (1.68 MB)
#  Trainable params: 147,212 (575.05 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 294,426 (1.12 MB)

# %%
###################################################################################################
# Load best weights
attack_FCN_no_time.load_weights(checkpoint_path)

###################################################################################################
# Prediction
y_pred_prob_no_time = attack_FCN_no_time.predict(X_test_attack)
y_pred_no_time = np.argmax(y_pred_prob_no_time, axis=1)

###################################################################################################
# Classification Report
target_names = ['Backdoor',
                'DDoS_HTTP',
                'DDoS_ICMP',
                'DDoS_TCP',
                'OS_Fingerprinting',
                'Password',
                'Port_Scanning',
                'Ransomware',
                'SQL_injection',
                'Uploading',
                'Vulnerability_scanner',
                'XSS']
print(classification_report(y_test_attack, y_pred_no_time,target_names= target_names))

###################################################################################################
# Training and Validation Loss Plots
plt.plot(attack_FCN_no_time_hist.history['loss'], label='Training Loss', color='darkblue')
plt.plot(attack_FCN_no_time_hist.history['val_loss'], label='Val_Loss', color='red')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.show()


###################################################################################################
# ROC Curves for all Attack_type
def plot_roc_curve(y_true, y_pred, n_classes):
    # Binarize the output
    lb = LabelBinarizer()
    y_true = lb.fit_transform(y_true)
    y_pred = lb.transform(y_pred)

    # Compute ROC curve and ROC area for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_true[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    # Compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], _ = roc_curve(y_true.ravel(), y_pred.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

    # Compute macro-average ROC curve and ROC area
    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))
    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])
    mean_tpr /= n_classes
    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

    # Plot all ROC curves
    plt.figure(figsize=(8, 6))
    plt.plot(fpr["micro"], tpr["micro"],
             label=f'micro-average ROC curve (area = {roc_auc["micro"]:0.2f})',
             color='deeppink', linewidth=2)

    plt.plot(fpr["macro"], tpr["macro"],
             label=f'macro-average ROC curve (area = {roc_auc["macro"]:0.2f})',
             color='navy', linewidth=2)

    colors = ['red', 'green', 'purple', 'brown', 'pink', 'gray', 'olive',
              'cyan', 'orange', 'yellow', 'black', 'blue', 'magenta']

    ## plot micro and macro auc-roc curve
    type_mapping = {
    'Backdoor': 0,
    'DDoS_HTTP': 1,
    'DDoS_ICMP': 2,
    'DDoS_TCP': 3,
    'OS_Fingerprinting': 4,
    'Password': 5,
    'Port_Scanning': 6,
    'Ransomware': 7,
    'SQL_injection': 8,
    'Uploading': 9,
    'Vulnerability_scanner': 10,
    'XSS': 11} 
    reverse_type_mapping = {v: k for k, v in type_mapping.items()}
    for i, color in zip(range(n_classes), colors):
        # class_name = lb.classes_[i]
        class_name = reverse_type_mapping[lb.classes_[i]]
        plt.plot(fpr[i], tpr[i], color=color, lw=1,
             label=f'ROC curve of {class_name} (area = {roc_auc[i]:0.2f})',
             linestyle='--')

    plt.plot([0, 1], [0, 1], 'k--', lw=2)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend(loc='lower right')
    plt.show()
plot_roc_curve(y_test_attack, y_pred_no_time, n_classes=len(np.unique(y_test_attack)))
# Out:
# 8376/8376 ━━━━━━━━━━━━━━━━━━━━ 4s 427us/step
#                        precision    recall  f1-score   support
#
#              Backdoor       0.99      0.94      0.97      7459
#             DDoS_HTTP       0.80      0.90      0.85     44658
#             DDoS_ICMP       1.00      1.00      1.00     43715
#              DDoS_TCP       1.00      1.00      1.00     42422
#     OS_Fingerprinting       1.00      0.84      0.92       300
#              Password       0.78      0.88      0.83     44242
#         Port_Scanning       0.87      1.00      0.93      6769
#            Ransomware       0.93      0.87      0.90      3278
#         SQL_injection       0.88      0.62      0.73     15361
#             Uploading       0.90      0.75      0.82     11290
# Vulnerability_scanner       0.99      0.93      0.96     43759
#                   XSS       0.88      0.39      0.54      4775
#
#              accuracy                           0.91    268028
#             macro avg       0.92      0.84      0.87    268028
#          weighted avg       0.91      0.91      0.90    268028

# %% [markdown]
# # Combining Both AE and FCN

# %%
def combined_predict_no_time(X_test):
    # Step 1: Autoencoder Prediction for Anomaly Detection
    reconstruction = ae_no_time.predict(X_test)
    reconstruction_error = np.mean(np.square(X_test - reconstruction), axis=1)
    
    # Determine anomalies based on threshold chosen when evaluating AE
    threshold = optimal_threshold

    # based on threshold determine which are normal
    is_anomaly = reconstruction_error > threshold

    y_pred = np.full(len(X_test), 12)  # Initialize predictions as "Normal" (or 12)

    # Classify anomalies with the FCN model
    if np.any(is_anomaly):
        anomaly_data = X_test[is_anomaly]
        y_pred_anomaly = attack_FCN_no_time.predict(anomaly_data).argmax(axis=1)  # Get predicted attack class
        y_pred[is_anomaly] = y_pred_anomaly
    return y_pred

###################################################################################################
# Classification Report
final_y_pred_no_time = combined_predict_no_time(X_test)
target_names = ['Backdoor',
                'DDoS_HTTP',
                'DDoS_ICMP',
                'DDoS_TCP',
                'OS_Fingerprinting',
                'Password',
                'Port_Scanning',
                'Ransomware',
                'SQL_injection',
                'Uploading',
                'Vulnerability_scanner',
                'XSS',
                'Normal']
print(classification_report(y_test, final_y_pred_no_time,target_names=target_names)) 


###################################################################################################
# ROC Curves for all Attack_type
def plot_roc_curve(y_true, y_pred, n_classes):
    # Binarize the output
    lb = LabelBinarizer()
    y_true = lb.fit_transform(y_true)
    y_pred = lb.transform(y_pred)

    # Compute ROC curve and ROC area for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_true[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    # Compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], _ = roc_curve(y_true.ravel(), y_pred.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

    # Compute macro-average ROC curve and ROC area
    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))
    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])
    mean_tpr /= n_classes
    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

    # Plot all ROC curves
    plt.figure(figsize=(8, 6))
    plt.plot(fpr["micro"], tpr["micro"],
             label=f'micro-average ROC curve (area = {roc_auc["micro"]:0.2f})',
             color='deeppink', linewidth=2)

    plt.plot(fpr["macro"], tpr["macro"],
             label=f'macro-average ROC curve (area = {roc_auc["macro"]:0.2f})',
             color='navy', linewidth=2)

    colors = ['red', 'green', 'purple', 'brown', 'pink', 'gray', 'olive',
              'cyan', 'orange', 'yellow', 'black', 'blue', 'magenta']

    ## plot micro and macro auc-roc curve
    type_mapping = {
    'Backdoor': 0,
    'DDoS_HTTP': 1,
    'DDoS_ICMP': 2,
    'DDoS_TCP': 3,
    'OS_Fingerprinting': 4,
    'Password': 5,
    'Port_Scanning': 6,
    'Ransomware': 7,
    'SQL_injection': 8,
    'Uploading': 9,
    'Vulnerability_scanner': 10,
    'XSS': 11,
    'Normal':12} 
    reverse_type_mapping = {v: k for k, v in type_mapping.items()}
    for i, color in zip(range(n_classes), colors):
        # class_name = lb.classes_[i]
        class_name = reverse_type_mapping[lb.classes_[i]]
        plt.plot(fpr[i], tpr[i], color=color, lw=1,
             label=f'ROC curve of {class_name} (area = {roc_auc[i]:0.2f})',
             linestyle='--')

    plt.plot([0, 1], [0, 1], 'k--', lw=2)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend(loc='lower right')
    plt.show()
plot_roc_curve(y_test, final_y_pred_no_time, n_classes=len(np.unique(y_test)))
# Out:
# 19852/19852 ━━━━━━━━━━━━━━━━━━━━ 5s 269us/step
# 8381/8381 ━━━━━━━━━━━━━━━━━━━━ 3s 406us/step
#                        precision    recall  f1-score   support
#
#              Backdoor       0.99      0.94      0.97      7459
#             DDoS_HTTP       0.80      0.90      0.85     44658
#             DDoS_ICMP       1.00      1.00      1.00     43715
#              DDoS_TCP       1.00      1.00      1.00     42422
#     OS_Fingerprinting       1.00      0.84      0.92       300
#              Password       0.78      0.88      0.83     44242
#         Port_Scanning       0.85      1.00      0.92      6769
#            Ransomware       0.93      0.87      0.90      3278
#         SQL_injection       0.88      0.62      0.73     15361
#             Uploading       0.90      0.75      0.82     11290
# Vulnerability_scanner       0.99      0.93      0.96     43759
#                   XSS       0.88      0.39      0.54      4775
#                Normal       1.00      1.00      1.00    367217
#
#              accuracy                           0.96    635245
#             macro avg       0.92      0.86      0.88    635245
#          weighted avg       0.96      0.96      0.96    635245

# %% [markdown]
# # Extract Embeddings

# %%
# Extract the embedding layer output
embedding_layer = attack_FCN_no_time.get_layer(index=-1) 
embeddings = embedding_layer.weights[0]  # The weights of the embedding layer

print(embedding_layer)
print(embeddings.shape)
# Out:
# <Dense name=dense_44, built=True>
# (192, 12)

# %%
input_layer = attack_FCN_no_time.get_layer(index=0)
input_weights = input_layer.get_weights()[0]
print(input_layer)
print(input_weights.shape)
print(input_layer.input)
# Out:
# <Dense name=dense_40, built=True>
# (98, 448)
# <KerasTensor shape=(None, 98), dtype=float32, sparse=None, name=keras_tensor_613>

# %%
embedding_model = Model(inputs=input_layer.input, outputs=embedding_layer.output)

# %%
n_samples = 10000
embeddings = embedding_model.predict(X_train_attack[:n_samples])
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step

# %%
LOGS_DIR = os.path.join(os.getcwd(), 'logs')

type_mapping = {
    'Backdoor': 0,
    'DDoS_HTTP': 1,
    'DDoS_ICMP': 2,
    'DDoS_TCP': 3,
    'OS_Fingerprinting': 4,
    'Password': 5,
    'Port_Scanning': 6,
    'Ransomware': 7,
    'SQL_injection': 8,
    'Uploading': 9,
    'Vulnerability_scanner': 10,
    'XSS': 11,
    'Normal':12} 
reverse_type_mapping = {v: k for k, v in type_mapping.items()}

labels = y_train_attack[:n_samples]["Attack_type"].to_list()
labels = [reverse_type_mapping[label] for label in labels]

if not os.path.exists(LOGS_DIR):
    os.makedirs(LOGS_DIR)

with open(os.path.join(LOGS_DIR, "metadata.tsv"), "w") as f:
    for label in labels:
        f.write(f"{label}\n")

np.savetxt(os.path.join(LOGS_DIR, "embeddings.tsv"), embeddings, delimiter="\t")
